# %%
import requests

# %%
url = 'http://localhost:9696/predict'

# %%
borrower_profile = {'person_age': 22,
 'person_income': 30000,
 'person_emp_length': 2.0,
 'loan_amnt': 3600,
 'loan_int_rate': 10.99,
 'loan_percent_income': 0.12,
 'person_home_ownership_MORTGAGE': False,
 'person_home_ownership_OTHER': False,
 'person_home_ownership_OWN': False,
 'person_home_ownership_RENT': True,
 'loan_intent_DEBTCONSOLIDATION': False,
 'loan_intent_EDUCATION': False,
 'loan_intent_HOMEIMPROVEMENT': False,
 'loan_intent_MEDICAL': False,
 'loan_intent_PERSONAL': False,
 'loan_intent_VENTURE': True,
 'loan_grade_A': False,
 'loan_grade_B': True,
 'loan_grade_C': False,
 'loan_grade_D': False,
 'loan_grade_E': False,
 'loan_grade_F': False,
 'loan_grade_G': False
 }

request = requests.post(url, json=borrower_profile).json()

request
# Out:
# {'default': False, 'default_probability': 0.012634284794330597}
